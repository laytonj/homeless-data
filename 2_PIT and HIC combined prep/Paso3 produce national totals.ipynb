# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
phSt = pd.read_excel('output_files_paso1_unclean/pitHicAllStUnclean.xlsx', index_col=0)

# %%
phSt
# Out:
#     year  numCoCs  totalH  shelH  unshelH  totalIndiv  shelIndiv  unshelIndiv  \
# st
# AK  2007        2    1642   1387      255        1062        891          171
# AL  2007        8    5452   3796     1656        4184       2823         1361
# AR  2007        9    3836   2285     1551        2987       1766         1221
# AZ  2007        3   14646   8618     6028       10020       4423         5597
# CA  2007       42  138986  48511    90475      110952      30497        80455
# CO  2007        3   14225   6971     7254        6844       3054         3790
# CT  2007       12    4482   3671      811        3173       2456          717
# DC  2007        1    5320   4980      340        3717       3377          340
# DE  2007        1    1061    854      207         716        530          186
# FL  2007       27   48069  20529    27540       33040      12772        20268
# GA  2007        7   19639   8341    11298       12521       5743         6778
# ...

# %% [markdown]
# ### Sum all columns by year, set year as the index

# %%
phGrouped = phSt.groupby(by='year', as_index=True).sum()
phGrouped
# Out:
#       numCoCs  totalH   shelH  unshelH  totalIndiv  shelIndiv  unshelIndiv  \
# year
# 2007      461  647258  391401   255857      412700     213073       199627
# 2008      448  639784  386361   253423      404525     204855       199670
# 2009      450  630227  403308   226919      392131     215995       176136
# 2010      444  637077  403543   233534      395140     212218       182922
# 2011      432  623788  392316   231472      387613     205834       181779
# 2012      425  621553  390155   231398      382156     199159       182997
# 2013      415  590364  394698   195666      368174     203127       165047
# 2014      414  576450  401051   175399      360189     209148       151041
# 2015      406  564708  391440   173268      358422     205616       152806
# 2016      403  549928  373571   176357      355212     198008       157204
# 2017      400  553742  360867   192875      369081     193144       175937
#
# ...

# %% [markdown]
# ### Write to Excel

# %%
writer = pd.ExcelWriter('output_files_paso3/pitHicNtnl.xlsx')
phGrouped.to_excel(writer,'pitHicNtnl')
writer.save()
